# %% [markdown]
# # Computer Vision Image annotations

# %% [markdown]
# ### Import statements

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def imshow(img):
    plt.figure(figsize = (10,7))
    plt.imshow(img)

# %%
cv2.__version__
# Out:
# '4.0.1'

# %% [markdown]
# ### To edit an image making a copy of it is always a good idea!

# %%
# Load an image
# And make a copy of the original image to avoid manipulating the original image
img = cv2.imread('img/blue-red-flowers.png')
plt.figure(figsize = (20,15));
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB));

# %% [markdown]
# [Hint](# "Numpy .copy function")

# %% [markdown]
# ## Drawing

# %% [markdown]
# ### Drawing lines

# %%
copy_flower = img.copy()

# %%
# Draw some lines on top of the image 
green = (0,255,0)
cv2.line()
np.array()
cv2.line(copy_flower,(1000,500),(1800,2000), green,5)
# Out:
# array([[[ 75,  80,  89],
#         [ 72,  77,  86],
#         [ 66,  71,  80],
#         ...,
#         [ 55, 120, 134],
#         [ 56,  98, 111],
#         [ 58,  84,  98]],
#
#        [[ 71,  78,  87],
#         [ 68,  75,  84],
#         [ 64,  69,  78],
#         ...,
#         [ 52,  96, 109],
#         [ 59,  87,  98],
#         [ 64,  84,  95]],
#
#        [[ 68,  75,  84],
#         [ 65,  72,  81],
#         [ 61,  68,  77],
#         ...,
#         [ 73,  88,  97],
#         [ 82,  93, 101],
#         [ 88,  99, 107]],
#
#        ...,
#
#        [[ 46,  45,  31],
#         [ 49,  46,  31],
#         [ 49,  47,  29],
#         ...,
#         [ 19,  25,  48],
#         [ 21,  27,  50],
#         [ 23,  28,  53]],
#
#        [[ 44,  42,  31],
#         [ 44,  42,  31],
#         [ 47,  44,  30],
#         ...,
#         [ 19,  25,  48],
#         [ 21,  27,  50],
#         [ 23,  28,  53]],
#
#        [[ 41,  38,  30],
#         [ 42,  39,  31],
#         [ 43,  41,  31],
#         ...,
#         [ 19,  25,  48],
#         [ 21,  27,  50],
#         [ 23,  28,  53]]], dtype=uint8)

# %%
cv2.imshow(copy_coco)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c39d503a7d6d> in <module>
# ----> 1 cv2.imshow(copy_coco)
#
# TypeError: imshow() missing required argument 'mat' (pos 2)

# %% [markdown]
# [Hint](# "cv2.line function")

# %% [markdown]
# ### Circles

# %%
# Draw some circles on top of the image
cv2.circle()

# %% [markdown]
# [Hint](# "cv2.circle")

# %% [markdown]
# ### Ellipses

# %%
# Draw some elipses on top of the image
cv2.ellipse(copy_coco,(500,500),(100,300),0,0,179,green,-1)
imshow(copy_coco)

# %% [markdown]
# [Hint](# "cv2.ellipse")

# %% [markdown]
# ### Poligons

# %%
# Lets draw some poligons, first declare the points of the poligon
copy_coco=img.copy()
points = np.array([[
    [10,5],
    [1000,1000],
    [2000,2000],
    [2200,1700]
]])
cv2.polylines(copy_coco,points,True,green,5)
imshow(copy_coco)

# %% [markdown]
# [Hint](# "Example: np.array([[10,5],[120,130],[170,120],[250,210]], np.int32)")

# %%
# Draw the poligon on top of the image

# %%
###Custom Font

# %%
text_to_show = "Custom Font"
   
# Load image in OpenCV  
image = cococay.copy()
   
# Convert the image to RGB (OpenCV uses BGR)  
cv2_im_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)  
   
# Transform the cv2 image to PIL  
pil_im = Image.fromarray(cv2_im_rgb)  
   
draw = ImageDraw.Draw(pil_im)  

# use a truetype font  
#font = ImageFont.truetype("impact.ttf", 80)    
font = ImageFont.truetype("img/Welcome.ttf", 800)    

draw.text((50, 600), text_to_show, (255,255,255), font=font)  
   
# Get back the image to OpenCV  
cv2_im_processed = cv2.cvtColor(np.array(pil_im), cv2.COLOR_RGB2BGR)  

plt.figure(figsize = (20,15))
imshow(cv2_im_processed);

# %% [markdown]
# [Hint](# "cv2.polylines(img_copy,[pts],False,(255,0,0),3)")

# %% [markdown]
# ### Add an overlay on top of an image

# %%
# Load an image and create a copy of it you can call it overlay
# Create a rectangle with a fill color (-1) on top of the overlay image
# Combine both images setting some opacity on the overlay
# Add some text on top of the overlay and show the image on screen

# %% [markdown]
# [Hint](# "cv2.addWeighted")

# %%
copy_coco=img.copy()
overlay = cococay.copy()

cv2.rectangle(overlay,(0,0),(1000,1000),(0,0,0)),-1)

# %%
opacity =0.5
img_2w = cv2.addWeighted(copy_coco,opacity,overlay,1-opacity,0)
imshow(img_2w)
